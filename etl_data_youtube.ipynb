# %%
# token github: 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

import pandas as pd
from googleapiclient.discovery import build

# Reemplaza 'YOUR_API_KEY' con tu clave de API
api_key = 'AIzaSyBJLr_to6EbYCIX4W2rj05brEvlSXIAh0M'
youtube = build('youtube', 'v3', developerKey=api_key)

# Reemplaza 'YOUR_CHANNEL_ID' con el ID de tu canal
channel_id = 'UCAUTqKNb0xxEw-eh_aGLYDQ'

# Obtener estadísticas del canal
channel_response = youtube.channels().list(
    part='statistics',
    id=channel_id
).execute()

# Obtener todos los videos del canal
videos_response = youtube.channels().list(
    part='contentDetails',
    id=channel_id
).execute()

# Obtener la lista de reproducción de videos del canal
playlist_id = videos_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# Obtener estadísticas de videos de la lista de reproducción
playlist_items_response = youtube.playlistItems().list(
    part='contentDetails',
    playlistId=playlist_id,
    maxResults=50  # Puedes ajustar la cantidad de videos que deseas obtener
).execute()

# Obtener IDs de video
video_ids = [item['contentDetails']['videoId'] for item in playlist_items_response['items']]

# Obtener estadísticas de videos específicos
videos_response = youtube.videos().list(
    part='statistics,snippet',
    id=','.join(video_ids)
).execute()

# Crear DataFrame
df_data = []

# Procesar datos y agregar a DataFrame
for video_stat in videos_response['items']:
    df_data.append({
        'Video ID': video_stat['id'],
        'Título': video_stat['snippet']['title'],
        'Reproducciones': video_stat['statistics'].get('viewCount', 0),
        'Me gusta': video_stat['statistics'].get('likeCount', 'No disponible'),
        'Comentarios': video_stat['statistics'].get('commentCount', 'No disponible'),
        'Fecha de publicación': video_stat['snippet']['publishedAt']
    })

# Crear DataFrame
df = pd.DataFrame(df_data)

# Imprimir DataFrame
df.head()
# Out:
#       Video ID                                             Título  \
# 0  nB_1qJ_7C_k  Proyecto individual N°1 del bootcamp SoyHenry ...
#
#   Reproducciones Me gusta Comentarios  Fecha de publicación
# 0             84        1           0  2023-02-21T16:26:12Z
